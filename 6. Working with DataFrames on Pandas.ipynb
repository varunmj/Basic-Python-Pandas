# %%
import pandas as pd

# %%
orders = pd.read_excel("./Sample - Superstore Sales.xls",0)

# %%
orders.head(3)
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity     Sales  \
# 0       1         3 2010-10-13            Low               6    261.54
# 1      49       293 2012-10-01           High              49  10123.02
# 2      50       293 2012-10-01           High              27    244.57
#
#    Discount       Ship Mode    Profit  Unit Price    ...      \
# 0      0.04     Regular Air -213.2500       38.94    ...
# 1      0.07  Delivery Truck  457.8100      208.16    ...
# 2      0.01     Regular Air   46.7075        8.69    ...
#
#         Customer Name Province   Region Customer Segment Product Category  \
# 0  Muhammed MacIntyre  Nunavut  Nunavut   Small Business  Office Supplies
# 1        Barry French  Nunavut  Nunavut         Consumer  Office Supplies
# 2        Barry French  Nunavut  Nunavut         Consumer  Office Supplies
#
#              Product Sub-Category  \
# 0          Storage & Organization
# 1                      Appliances
# ...

# %%
orders.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Order Priority', 'Order Quantity',
#        'Sales', 'Discount', 'Ship Mode', 'Profit', 'Unit Price',
#        'Shipping Cost', 'Customer Name', 'Province', 'Region',
#        'Customer Segment', 'Product Category', 'Product Sub-Category',
#        'Product Name', 'Product Container', 'Product Base Margin',
#        'Ship Date'],
#       dtype='object')

# %% [markdown]
# ### Subsetting and creating new dataframe :

# %%
order_subset =pd.DataFrame(orders,columns=['Row ID', 'Order ID', 'Order Date', 'Order Priority', 'Order Quantity',
       'Sales', 'Discount', 'Ship Mode', 'Profit', 'Unit Price',
       'Shipping Cost', 'Customer Name', 'Province', 'Region',
       'Customer Segment'])

# %%
order_subset.head()
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity       Sales  \
# 0       1         3 2010-10-13            Low               6    261.5400
# 1      49       293 2012-10-01           High              49  10123.0200
# 2      50       293 2012-10-01           High              27    244.5700
# 3      80       483 2011-07-10           High              30   4965.7595
# 4      85       515 2010-08-28  Not Specified              19    394.2700
#
#    Discount       Ship Mode     Profit  Unit Price  Shipping Cost  \
# 0      0.04     Regular Air  -213.2500       38.94          35.00
# 1      0.07  Delivery Truck   457.8100      208.16          68.02
# 2      0.01     Regular Air    46.7075        8.69           2.99
# 3      0.08     Regular Air  1198.9710      195.99           3.99
# 4      0.08     Regular Air    30.9400       21.78           5.94
#
#         Customer Name Province   Region Customer Segment
# 0  Muhammed MacIntyre  Nunavut  Nunavut   Small Business
# ...

# %% [markdown]
# ### Subsetting the column

# %%
order_subset["Order Date"]
# Out:
# 0      2010-10-13
# 1      2012-10-01
# 2      2012-10-01
# 3      2011-07-10
# 4      2010-08-28
# 5      2010-08-28
# 6      2011-06-17
# 7      2011-06-17
# 8      2011-03-24
# 9      2010-02-26
# 10     2010-11-23
# 11     2010-11-23
# 12     2012-06-08
# 13     2012-06-08
# 14     2012-08-04
# 15     2011-05-30
# 16     2009-11-25
# 17     2012-02-14
# 18     2012-02-14
# 19     2012-04-15
# 20     2012-04-15
# 21     2010-03-12
# 22     2010-03-12
# 23     2011-03-09
# 24     2011-03-09
# 25     2012-08-04
# 26     2011-05-06
# 27     2010-12-23
# 28     2010-11-08
# 29     2012-10-21
#           ...
# 8369   2012-09-03
# 8370   2012-09-03
# 8371   2010-07-29
# 8372   2010-07-29
# 8373   2010-04-20
# 8374   2010-04-20
# 8375   2009-07-02
# 8376   2009-07-02
# 8377   2012-12-16
# 8378   2010-02-04
# 8379   2012-04-28
# 8380   2012-04-28
# 8381   2011-06-28
# 8382   2009-04-26
# 8383   2011-05-06
# 8384   2011-05-06
# 8385   2010-11-07
# 8386   2010-05-15
# 8387   2010-05-15
# ...

# %% [markdown]
# ### with .(dot) notation :

# %%
order_subset.Sales
# Out:
# 0         261.5400
# 1       10123.0200
# 2         244.5700
# 3        4965.7595
# 4         394.2700
# 5         146.6900
# 6          93.5400
# 7         905.0800
# 8        2781.8200
# 9         228.4100
# 10        196.8500
# 11        124.5600
# 12        716.8400
# 13       1474.3300
# 14         80.6100
# 15       1815.4900
# 16        248.2600
# 17       4462.2300
# 18        663.7840
# 19        834.9040
# 20       2480.9205
# 21         59.0300
# 22         97.4800
# 23        511.8300
# 24        184.9900
# 25         80.9000
# 26         67.2400
# 27      12028.2300
# 28        370.4800
# 29        278.0000
#            ...
# 8369       22.8900
# 8370      271.8500
# 8371    12719.7000
# 8372      109.7800
# 8373      561.6600
# 8374     1851.6200
# 8375     2453.3000
# 8376      147.0200
# 8377     1558.9425
# 8378      257.3900
# 8379      163.5400
# 8380     2390.5400
# 8381     4644.8700
# 8382       38.9600
# 8383      978.4000
# 8384     5126.4180
# ...

# %% [markdown]
# ### Deleting the column from the dataframe:

# %%
del order_subset["Sales"]

# %%
order_subset.head()
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity  Discount  \
# 0       1         3 2010-10-13            Low               6      0.04
# 1      49       293 2012-10-01           High              49      0.07
# 2      50       293 2012-10-01           High              27      0.01
# 3      80       483 2011-07-10           High              30      0.08
# 4      85       515 2010-08-28  Not Specified              19      0.08
#
#         Ship Mode     Profit  Unit Price  Shipping Cost       Customer Name  \
# 0     Regular Air  -213.2500       38.94          35.00  Muhammed MacIntyre
# 1  Delivery Truck   457.8100      208.16          68.02        Barry French
# 2     Regular Air    46.7075        8.69           2.99        Barry French
# 3     Regular Air  1198.9710      195.99           3.99       Clay Rozendal
# 4     Regular Air    30.9400       21.78           5.94      Carlos Soltero
#
#   Province   Region Customer Segment
# 0  Nunavut  Nunavut   Small Business
# ...
