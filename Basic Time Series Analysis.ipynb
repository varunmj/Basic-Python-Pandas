# %%
import pandas as pd
ioc = pd.read_csv("./IOC-finance.csv")

# %%
ioc.head()
# Out:
#   Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0    IOC     EQ  02-Jul-2007      443.60       445.0      456.90     438.20
# 1    IOC     EQ  03-Jul-2007      454.15       458.1      464.95     451.05
# 2    IOC     EQ  04-Jul-2007      453.55       454.0      460.90     448.30
# 3    IOC     EQ  05-Jul-2007      453.05       451.0      451.05     440.00
# 4    IOC     EQ  06-Jul-2007      441.40       440.0      443.00     433.30
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0      452.25       454.15         451.02                 197689
# 1      453.90       453.55         459.50                 239033
# 2      448.30       453.05         453.47                 224088
# 3      442.00       441.40         443.13                  73406
# 4      433.30       435.95         439.26                 335044
#
#        Turnover No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# ...

# %%
df = ioc.drop(["Symbol","Series"],axis =1)

# %%
df.tail()
# Out:
#             Date  Prev Close  Open Price  High Price  Low Price  Last Price  \
# 245  24-Jun-2008      358.20      351.50       360.0     345.30       353.0
# 246  25-Jun-2008      352.60      348.35       360.8     345.30       356.4
# 247  26-Jun-2008      358.30      360.40       365.0     345.25       349.0
# 248  27-Jun-2008      351.65      342.00       344.9     330.60       340.0
# 249  30-Jun-2008      341.10      355.00       355.0     329.00       331.0
#
#      Close Price  Average Price  Total Traded Quantity      Turnover  \
# 245       352.60         350.98                 540465  1.896900e+08
# 246       358.30         354.50                 366533  1.299369e+08
# 247       351.65         355.43                 863797  3.070170e+08
# 248       341.10         337.87                 487183  1.646033e+08
# 249       332.30         333.38                 238971  7.966786e+07
#
#     No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# ...

# %%
bizday = pd.date_range(start='02-07-2007',end='30-06-2008',freq='B')
bizday
# Out:
# DatetimeIndex(['2007-02-07', '2007-02-08', '2007-02-09', '2007-02-12',
#                '2007-02-13', '2007-02-14', '2007-02-15', '2007-02-16',
#                '2007-02-19', '2007-02-20',
#                ...
#                '2008-06-17', '2008-06-18', '2008-06-19', '2008-06-20',
#                '2008-06-23', '2008-06-24', '2008-06-25', '2008-06-26',
#                '2008-06-27', '2008-06-30'],
#               dtype='datetime64[ns]', length=364, freq='B')

# %%
from pandas.tseries.holiday import USFederalHolidayCalendar
from pandas.tseries.offsets import CustomBusinessDay

us_holiday = CustomBusinessDay(calendar=USFederalHolidayCalendar())

USBizday = pd.date_range(start='02-07-2007',end='30-06-2008',freq=us_holiday)
USBizday
# Out:
# DatetimeIndex(['2007-02-07', '2007-02-08', '2007-02-09', '2007-02-12',
#                '2007-02-13', '2007-02-14', '2007-02-15', '2007-02-16',
#                '2007-02-20', '2007-02-21',
#                ...
#                '2008-06-17', '2008-06-18', '2008-06-19', '2008-06-20',
#                '2008-06-23', '2008-06-24', '2008-06-25', '2008-06-26',
#                '2008-06-27', '2008-06-30'],
#               dtype='datetime64[ns]', length=352, freq='C')
